# %% [markdown]
# # Importing Libraries

# %% [markdown]
# import matplotlib.pyplot as plot
# from warnings import filterwarnings

# %% [markdown]
# # Importing Dataset

# %% [markdown]
# df=ppd.read_csv("C:/Users/User/CARPREDICTION/CARPREDICTION.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    customer name  customer e-mail  country  gender        age  annual Salary  \
# 0            288              139       27       0  41.851720    62812.09301
# 1            168              224       17       0  40.870623    66646.89292
# 2            311              498        1       1  43.152897    53798.55112
# 3            204              307       41       1  58.271369    79370.03798
# 4             70              241       26       1  57.313749    59729.15130
#
#    credit card debt    net worth  car purchase amount
# 0      11609.380910  238961.2505          35321.45877
# 1       9572.957136  530973.9078          45115.52566
# 2      11160.355060  638467.1773          42925.70921
# 3      14426.164850  548599.0524          67422.36313
# 4       5358.712177  560304.0671          55915.46248

# %%
df.describe()
# Out:
#        customer name  customer e-mail     country      gender         age  \
# count     500.000000       500.000000  500.000000  500.000000  500.000000
# mean      249.278000       249.500000  102.682000    0.506000   46.241674
# std       144.154854       144.481833   60.388263    0.500465    7.978862
# min         0.000000         0.000000    0.000000    0.000000   20.000000
# 25%       124.750000       124.750000   52.000000    0.000000   40.949969
# 50%       249.500000       249.500000  100.500000    1.000000   46.049901
# 75%       374.250000       374.250000  156.000000    1.000000   51.612263
# max       497.000000       499.000000  210.000000    1.000000   70.000000
#
#        annual Salary  credit card debt       net worth  car purchase amount
# count     500.000000        500.000000      500.000000           500.000000
# mean    62127.239608       9607.645049   431475.713625         44209.799218
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    int64
#  1   customer e-mail      500 non-null    int32
#  2   country              500 non-null    int32
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int32(2), int64(2)
# memory usage: 31.4 KB

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Correlation

# %%
ssb.heatmap(df.corr(), cmap='cool', annot = True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                      customer name  customer e-mail   country    gender  \
# customer name             1.000000        -0.034360  0.012102 -0.021926
# customer e-mail          -0.034360         1.000000 -0.031326  0.073458
# country                   0.012102        -0.031326  1.000000 -0.009850
# gender                   -0.021926         0.073458 -0.009850  1.000000
# age                       0.018092        -0.040885  0.016752 -0.064481
# annual Salary             0.038859         0.010627 -0.007640 -0.036499
# credit card debt          0.028952         0.019145  0.024502  0.024193
# net worth                -0.008116         0.048010  0.038831 -0.008395
# car purchase amount       0.031218         0.003429  0.023906 -0.066408
#
#                           age  annual Salary  credit card debt  net worth  \
# customer name        0.018092       0.038859          0.028952  -0.008116
# customer e-mail     -0.040885       0.010627          0.019145   0.048010
# ...

# %% [markdown]
# # Data Vidualization

# %%
from matplotlib.pyplot import figure
ssb.jointplot(x='annual Salary',y= 'car purchase amount', data=df, kind= 'scatter', color= 'Red')
figure(figsize=(3, 2), dpi=60)

# %%
ssb.countplot(x='credit card debt', data = df)
# Out:
# <AxesSubplot:xlabel='credit card debt', ylabel='count'>

# %%
ssb.distplot(df['credit card debt'], bins = 35, kde= True, color= 'red')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='credit card debt', ylabel='Density'>

# %%
ssb.barplot(df["annual Salary"], df["car purchase amount"])
plot.xlabel("annual Salary")
plot.ylabel("car purchase amount")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'car purchase amount')

# %% [markdown]
# # Train and test spliting

# %%
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()
  
df['customer name']= label_encoder.fit_transform(df['customer name'])
df['customer e-mail']= label_encoder.fit_transform(df['customer e-mail'])
df['country']= label_encoder.fit_transform(df['country'])

# %%
a=df.iloc[:,3:7]
b=df.iloc[:,-1]
a=nnp.array(x)
b=nnp.array(y)

# %%
from sklearn.model_selection import train_test_split
train_a, test_a, train_b, test_b = train_test_split(a, b, test_size = 0.2)

# %%
train_a.shape
# Out:
# (400, 4)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
train_a = sc.fit_transform(train_a)
test_a = sc.transform(test_a)

# %% [markdown]
# # Artificial neural network classification

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.7/1.7 MB 3.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 266.3/266.3 MB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 23.2/23.2 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 895.9/895.9 kB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 126.5/126.5 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 439.2/439.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.7/3.7 MB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 6.0/6.0 MB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 1.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 781.3/781.3 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import keras
import tensorflow as tfs
from keras.models import Sequential
from keras.layers import Dense

# %%
ANN = tfs.keras.models.Sequential()

# %%
ANN.add(Dense(units = 130,  activation = 'relu', input_dim = 5))
ANN.add(Dense(units = 130,  activation = 'relu'))   
ANN.add(Dense(1,  activation = 'sigmoid'))

# %%
ANN.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ANN.fit(train_a,train_b, batch_size = 20, epochs = 30)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 1s 3ms/step - loss: -21658.3359 - accuracy: 0.0000e+00
# Epoch 2/30
# 20/20 [==============================] - 0s 2ms/step - loss: -91859.7109 - accuracy: 0.0000e+00
# Epoch 3/30
# 20/20 [==============================] - 0s 2ms/step - loss: -230603.3438 - accuracy: 0.0000e+00
# Epoch 4/30
# 20/20 [==============================] - 0s 2ms/step - loss: -490543.5625 - accuracy: 0.0000e+00
# Epoch 5/30
# 20/20 [==============================] - 0s 3ms/step - loss: -945111.0625 - accuracy: 0.0000e+00
# Epoch 6/30
# 20/20 [==============================] - 0s 2ms/step - loss: -1665509.2500 - accuracy: 0.0000e+00
# Epoch 7/30
# 20/20 [==============================] - 0s 2ms/step - loss: -2731875.7500 - accuracy: 0.0000e+00
# Epoch 8/30
# 20/20 [==============================] - 0s 2ms/step - loss: -4223404.5000 - accuracy: 0.0000e+00
# Epoch 9/30
# ...

# %%
prediction_b = ANN.predict(test_a)
prediction_b = (prediction_b > 0.7)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score
r2_score(test_b, prediction_b)
# Out:
# -21.2862594273781
